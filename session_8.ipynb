# %%
import pandas as pd
churn_data=pd.read_csv(r"C:\Users\91937\Downloads\telecom_churn_data.csv")
churn_data
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
churn_data.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
churn_data.select_dtypes(exclude='object').columns
# Out:
# Index(['year', 'customer_id', 'age', 'no_of_days_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
churn_data['churn'].values
# Out:
# array([0., 0., 1., ..., 0., 0., 1.])

# %%
churn_data.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
churn_data.select_dtypes(exclude='integer').columns
# Out:
# Index(['phone_no', 'gender', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'maximum_days_inactive', 'churn'],
#       dtype='object')

# %%
churn1=churn_data['churn'].values
for values in 'churn':
     if values ==0:
         print("true")
     else:
         print("false")
# Out:
# false
# false
# false
# false
# false

# %%
churn_data.drop(['customer_id',
               'phone_no','year'],axis=1)
# Out:
#       gender  age  no_of_days_subscribed multi_screen mail_subscribed  \
# 0     Female   36                     62           no              no
# 1     Female   39                    149           no              no
# 2     Female   65                    126           no              no
# 3     Female   24                    131           no             yes
# 4     Female   40                    191           no              no
# ...      ...  ...                    ...          ...             ...
# 1995  Female   54                     75           no             yes
# 1996    Male   45                    127           no              no
# 1997     NaN   53                     94           no              no
# 1998    Male   40                     94           no              no
# 1999    Male   37                     73           no              no
#
#       weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# ...

# %%
churn_data.drop([1,2,3],axis=0)
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 4     2015       101653  351-8398  Female   40                    191
# 5     2015       101953  329-6603     NaN   31                     65
# 6     2015       103051  416-1845     NaN   54                     59
# 7     2015       103225  348-7193  Female   40                     50
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
churn_data['churn']=churn_data['churn'].map({1.0:'yes',0.0:'no'})
churn_data['churn']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1995    NaN
# 1996    NaN
# 1997    NaN
# 1998    NaN
# 1999    NaN
# Name: churn, Length: 2000, dtype: object
